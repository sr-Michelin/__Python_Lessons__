# %%
import numpy as np
from qiskit import (QuantumCircuit, execute, Aer)
from qiskit.visualization import plot_histogram

# %%
sim = Aer.get_backend('qasm_simulator')
circ = QuantumCircuit(5, 5)

circ.h(0)
circ.h(1)
circ.h(2)
circ.h(3)
circ.h(4)

circ.barrier()
circ.measure(range(5),range(5))

circ.draw('mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circ, backend=simulator, shots=2048).result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'00000': 65, '00001': 66, '10000': 51, '10001': 66, '10010': 50, '10011': 72, '10100': 62, '10101': 75, '10110': 69, '10111': 65, '11000': 69, '11001': 70, '11010': 60, '11011': 67, '11100': 58, '11101': 69, '11110': 73, '11111': 70, '00010': 72, '00011': 65, '00100': 68, '00101': 62, '00110': 59, '00111': 53, '01000': 65, '01001': 57, '01010': 65, '01011': 57, '01100': 55, '01101': 64, '01110': 63, '01111': 66}
