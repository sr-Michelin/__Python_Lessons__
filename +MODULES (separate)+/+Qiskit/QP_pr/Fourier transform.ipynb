# %%
import numpy as np
from qiskit import (QuantumCircuit, execute, Aer, assemble)
from qiskit.visualization import plot_histogram, plot_bloch_multivector
# N = 1 qub
sim = Aer.get_backend('qasm_simulator')
circ = QuantumCircuit(2, 2)

# %%
circ.x(0)
teta = np.pi/2
circ.p(teta, 0)
circ.h(0)
circ.barrier()
circ.h(0)
circ.draw('mpl',initial_state = True, scale = 1)

# %%
circ.measure(range(1),range(1))
circ.draw('mpl')

# %%
sv_sim = Aer.get_backend("statevector_simulator")
qobj = assemble(circ)
statevector = sv_sim.run(qobj).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circ, backend=simulator, shots=1024).result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'01': 1024}

# %%
# N = 3 qub
import numpy as np
from qiskit import (QuantumCircuit, execute, Aer, assemble)
from qiskit.visualization import plot_histogram
sim = Aer.get_backend('qasm_simulator')
circ = QuantumCircuit(3)

# %%
circ.x(0)
circ.x(2)

circ.barrier()

circ.h(2)
circ.cp(np.pi/2, 1, 2)
circ.cp(np.pi/4, 0, 2)

circ.h(1)
circ.cp(np.pi/2, 0, 1)

circ.h(0)

circ.swap(0,2)

circ.draw('mpl')

# %%
sv_sim = Aer.get_backend("statevector_simulator")
qobj = assemble(circ)
statevector = sv_sim.run(qobj).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
circ.measure_all()
circ.draw('mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circ, backend=simulator, shots=1024).result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'000': 132, '001': 135, '010': 126, '011': 126, '100': 132, '101': 117, '110': 123, '111': 133}

# %%
# N = 4 qub
import numpy as np
from qiskit import (QuantumCircuit, execute, Aer, assemble)
from qiskit.visualization import plot_histogram
sim = Aer.get_backend('qasm_simulator')
circ = QuantumCircuit(4)

# %%
# circ.x(0)
# circ.x(2)

#circ.barrier()

circ.h(3)
circ.cp(np.pi/8, 0, 3)
circ.cp(np.pi/4, 1, 3)
circ.cp(np.pi/2, 2, 3)
circ.barrier()

circ.h(2)
circ.cp(np.pi/4, 0, 2)
circ.cp(np.pi/2, 1, 2)
circ.barrier()

circ.h(1)
circ.cp(np.pi/2, 0, 1)

circ.h(0)

circ.swap(1,2)

circ.swap(0,3)

circ.draw('mpl')

# %%
sv_sim = Aer.get_backend("statevector_simulator")
qobj = assemble(circ)
statevector = sv_sim.run(qobj).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
circ.measure_all()
circ.draw('mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circ, backend=simulator, shots=1024).result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'0000': 62, '0001': 55, '0010': 58, '0011': 76, '0100': 60, '0101': 66, '0110': 63, '0111': 65, '1000': 72, '1001': 60, '1010': 64, '1011': 75, '1100': 54, '1101': 62, '1110': 52, '1111': 80}

# %%
# N = 3 qub
# practice 31.03.21
import numpy as np
from qiskit import (QuantumCircuit, execute, Aer, assemble)
from qiskit.visualization import plot_histogram, plot_bloch_multivector
sim = Aer.get_backend('qasm_simulator')
circ = QuantumCircuit(3)

# %%
circ.x(0)
circ.x(1)
circ.x(2)
circ.barrier()

circ.h(2)
circ.cp(np.pi/2, 1, 2)
circ.cp(np.pi/4, 0, 2)
circ.barrier()

circ.h(1)
circ.cp(np.pi/2, 0, 1)
circ.barrier()

circ.h(0)

circ.swap(0,2)

circ.measure_all()

circ.draw('mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circ, backend=simulator, shots=1024).result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'000': 140, '001': 115, '010': 137, '011': 122, '100': 135, '101': 131, '110': 123, '111': 121}

# %%
sv_sim = Aer.get_backend("statevector_simulator")
qobj = assemble(circ)
statevector = sv_sim.run(qobj).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
# N = 4 qub
# practice 31.03.21
import numpy as np
from qiskit import (QuantumCircuit, execute, Aer, assemble)
from qiskit.visualization import plot_histogram, plot_bloch_multivector
sim = Aer.get_backend('qasm_simulator')
circ = QuantumCircuit(4)

# %%
circ.x(0)
circ.x(1)
circ.x(2)
circ.x(3)
circ.barrier()

circ.h(3)
circ.cp(np.pi/2, 2, 3)
circ.cp(np.pi/4, 1, 3)
circ.cp(np.pi/8, 0, 3)
circ.barrier()

circ.h(2)
circ.cp(np.pi/2, 1, 2)
circ.cp(np.pi/4, 0, 2)
circ.barrier()

circ.h(1)
circ.cp(np.pi/2, 0, 1)
circ.barrier()

circ.h(0)
circ.barrier()

circ.swap(0,3)
circ.swap(1,2)


circ.measure_all()

circ.draw('mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circ, backend=simulator, shots=1024).result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'0000': 57, '0001': 59, '0010': 54, '0011': 68, '0100': 63, '0101': 59, '0110': 81, '0111': 63, '1000': 67, '1001': 78, '1010': 68, '1011': 58, '1100': 63, '1101': 63, '1110': 58, '1111': 65}

# %%
sv_sim = Aer.get_backend("statevector_simulator")
qobj = assemble(circ)
statevector = sv_sim.run(qobj).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
# N = 5 qub
# practice 31.03.21
import numpy as np
from qiskit import (QuantumCircuit, execute, Aer, assemble)
from qiskit.visualization import plot_histogram, plot_bloch_multivector
sim = Aer.get_backend('qasm_simulator')
circ = QuantumCircuit(5)

# %%
circ.x(0)
circ.x(1)
circ.x(2)
circ.x(3)
circ.x(4)
circ.barrier()

circ.h(4)
circ.cp(np.pi/2, 3, 4)
circ.cp(np.pi/4, 2, 4)
circ.cp(np.pi/8, 1, 4)
circ.cp(np.pi/16, 0, 4)
circ.barrier()

circ.h(3)
circ.cp(np.pi/2, 2, 3)
circ.cp(np.pi/4, 1, 3)
circ.cp(np.pi/8, 0, 3)
circ.barrier()

circ.h(2)
circ.cp(np.pi/2, 1, 2)
circ.cp(np.pi/4, 0, 2)
circ.barrier()

circ.h(1)
circ.cp(np.pi/2, 0, 1)
circ.barrier()

circ.h(0)
circ.barrier()

circ.swap(0,4)
circ.swap(1,3)

circ.measure_all()
circ.draw('mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circ, backend=simulator, shots=1024).result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'00000': 24, '00001': 38, '10000': 33, '10001': 27, '10010': 37, '10011': 51, '10100': 21, '10101': 29, '10110': 32, '10111': 37, '11000': 22, '11001': 30, '11010': 26, '11011': 31, '11100': 18, '11101': 37, '11110': 35, '11111': 29, '00010': 33, '00011': 41, '00100': 42, '00101': 22, '00110': 34, '00111': 44, '01000': 35, '01001': 35, '01010': 29, '01011': 36, '01100': 29, '01101': 37, '01110': 20, '01111': 30}

# %%
sv_sim = Aer.get_backend("statevector_simulator")
qobj = assemble(circ)
statevector = sv_sim.run(qobj).result().get_statevector()
plot_bloch_multivector(statevector)
